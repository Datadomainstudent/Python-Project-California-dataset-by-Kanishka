# %%
import pandas as pd
housing = pd.read_excel('housing.xlsx')
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
#1. What is the average median income of the data set and check the distribution of data using appropriate plots.
# Please explain the distribution of the plot.


import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average median income
average_median_income = housing['median_income'].mean()
print(f'Average Median Income: ${average_median_income:.2f}')

# Create a histogram to visualize the distribution
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.histplot(housing['median_income'], kde=True, color='orange')
plt.title('Distribution of Median Income')
plt.xlabel('Median Income')
plt.ylabel('Frequency')

# Show the plot
plt.grid(True)
plt.show()
# Out:
# Average Median Income: $3.87

# %%
#2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

import matplotlib.pyplot as plt

# Create a histogram to visualize the distribution of housing_median_age
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
plt.hist(housing['housing_median_age'], bins=20, edgecolor='black', color='lightblue')
plt.title('Distribution of Housing Median Age')
plt.xlabel('Housing Median Age')
plt.ylabel('Frequency')

# Show the plot
plt.grid(True)
plt.show()

# %%
#3. Show with the help of visualization, how median_income and median_house_values are related?
import matplotlib.pyplot as plt


# Create a scatter plot
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
plt.scatter(housing['median_income'], housing['median_house_value'],marker = 'h',edgecolor = 'w',alpha=0.5)
plt.title('Relationship Between Median Income and Median House Values')
plt.xlabel('Median Income')
plt.ylabel('Median House Values')

# Show the plot
#plt.grid(True)
plt.show()

# %%
#4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

import pandas as pd

# Create a new DataFrame by filtering out rows with missing 'total_bedrooms'
new_data = housing.dropna(subset=['total_bedrooms'])
housing

# Now, 'new_data' contains only the rows where 'total_bedrooms' is available
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.



# Calculate the mean of the "total_bedrooms" column
mean_total_bedrooms = housing['total_bedrooms'].mean()

# Create a new dataset by filling missing data with the mean value
new_data = housing.fillna({'total_bedrooms': mean_total_bedrooms})
print(new_data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#6Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

def calculate_median(housing):

   return housing.median()

new_dal = calculate_median(housing)
new_dal
# Out:
# <ipython-input-20-de27779b55ce>:5: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return housing.median()
# longitude               -118.4900
# latitude                  34.2600
# housing_median_age        29.0000
# total_rooms             2127.0000
# total_bedrooms           435.0000
# population              1166.0000
# households               409.0000
# median_income              3.5348
# median_house_value    179700.0000
# dtype: float64

# %%
#7. Plot latitude versus longitude and explain your observations.

import matplotlib.pyplot as plt

# Create a scatter plot of latitude versus longitude
plt.figure(figsize=(10, 6))
plt.scatter(housing['longitude'], housing['latitude'], c='blue', s=1)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Latitude vs. Longitude')

# Show the plot
plt.grid(True)
plt.show()

# %%
#8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# Create a new dataset where 'ocean_proximity' is 'Near ocean'
near_ocean_data = housing[housing['ocean_proximity'] == 'NEAR BAY']
print(near_ocean_data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 19067    -122.45     38.28                  20         3306           503.0
# 19068    -122.47     38.29                  14         3732           846.0
# 19069    -122.45     38.27                  25         5024           881.0
# 19077    -122.49     38.27                   8         5092           988.0
# 19104    -122.51     38.17                   8         5875          1115.0
#
# ...

# %%
#9. Find the mean and median of the median income for the data set created in question 8.

# Calculate the mean of median income
mean_median_income = near_ocean_data['median_income'].mean()

# Calculate the median of median income
median_median_income = near_ocean_data['median_income'].median()

print(f"Mean Median Income: {mean_median_income:.3f}")
print(f"Median Median Income: {median_median_income:.3f}")
# Out:
# Mean Median Income: 4.173
# Median Median Income: 3.819

# %%
#10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less,
# it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.


import pandas as pd


# Define a function to categorize the total bedrooms
def categorize_total_bedroom_size(total_bedrooms):
    if total_bedrooms <= 10:
        return 'small'
    elif 11 <= total_bedrooms < 1000:
        return 'medium'
    else:
        return 'large'

# Apply the function to create the new column
housing['total_bedroom_size'] = housing['total_bedrooms'].apply(categorize_total_bedroom_size)
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
